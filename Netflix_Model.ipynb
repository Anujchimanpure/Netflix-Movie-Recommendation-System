# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df=pd.read_csv("netflix_clean_data.csv")
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#    date_added  release_year rating   duration  \
# 0  25-09-2021          2020  PG-13     90 min
# 1  24-09-2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description duration_value  \
# 0  As her father nears the end of his life, filmm...             90
# 1  After crossing paths at a party, a Cape Town t...              2
#
#   duration_type                                            content
# 0           min                unknown documentaries united states
# 1       Seasons  ama qamata, khosi ngema, gail mabalane, thaban...

# %%
noword = TfidfVectorizer(stop_words = 'english')

# %%
#stop english grammar words

matrix = df['content']

# %%
# finds similarity

similar = cosine_similarity(matrix,matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 3
#       1 # finds similarity
# ----> 3 similar = cosine_similarity(matrix,matrix)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:1728, in cosine_similarity(X, Y, dense_output)
#    1675 @validate_params(
#    1676     {
#    1677         "X": ["array-like", "sparse matrix"],
#    (...)   1682 )
#    1683 def cosine_similarity(X, Y=None, dense_output=True):
#    1684     """Compute cosine similarity between samples in X and Y.
#    1685
#    1686     Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)   1726            [0.577, 0.816]])
#    1727     """
# -> 1728     X, Y = check_pairwise_arrays(X, Y)
#    1730     X_normalized = normalize(X, copy=True)
#    1731     if X is Y:
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:190, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, ensure_all_finite, ensure_2d, copy)
#     187     dtype = dtype_float
#     189 if Y is X or Y is None:
# --> 190     X = Y = check_array(
#     191         X,
#     192         accept_sparse=accept_sparse,
#     193         dtype=dtype,
#     194         copy=copy,
#     195         ensure_all_finite=ensure_all_finite,
#     196         estimator=estimator,
#     197         ensure_2d=ensure_2d,
#     198     )
#     199 else:
#     200     X = check_array(
#     201         X,
#     202         accept_sparse=accept_sparse,
#    (...)    207         ensure_2d=ensure_2d,
#     208     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1051         array = xp.astype(array, dtype, copy=False)
#    1052     else:
# -> 1053         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1054 except ComplexWarning as complex_warning:
#    1055     raise ValueError(
#    1056         "Complex data not supported\n{}\n".format(array)
#    1057     ) from complex_warning
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:757, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     755     array = numpy.array(array, order=order, dtype=dtype)
#     756 else:
# --> 757     array = numpy.asarray(array, order=order, dtype=dtype)
#     759 # At this point array is a NumPy ndarray. We convert it to an array
#     760 # container that is consistent with the input's namespace.
#     761 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'unknown documentaries united states'

# %%
def recommend_movie(title):
    title = title.lower().strip()

    df['title_clean'] = df['title'].str.lower().str.strip()

    if title not in df['title_clean'].values:
        print("Movie not found in dataset")
        return

    idx = df[df['title_clean'] == title].index[0]

    similar_score = list(enumerate(similar[idx]))
    similar_score = sorted(similar_score, key=lambda x: x[1], reverse=True)

    print("Recommended Movies:")
    for i in similar_score[1:6]:
        print(df.iloc[i[0]]['title'])

# %%
recommend_movie('Kota Factory')
# Out:
# Recommended Movies:
# Chaman Bahaar
# The Big Day
# Yeh Meri Family
# Dancing Angels
# Find Yourself

# %%
recommend_movie('inception')
# Out:
# Recommended Movies:
# Before the Flood
# Peaky Blinders
# Brick
# Dragonheart
# Transcendence

# %%
import pandas as pd
import pickle

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("netflix_clean_data.csv")

# Use only needed columns
df = df[['title', 'description']]

# Handle missing values
df['description'] = df['description'].fillna('')

# %%
tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(df['description'])

# %%
similarity = cosine_similarity(tfidf_matrix)

# %%
with open("similarity.pkl", "wb") as f:
    pickle.dump(similarity, f)

# %%
print(df.columns.tolist())
# Out:
# ['title', 'description']

# %%
import pandas as pd

df = pd.read_csv("netflix_clean_data.csv")
print(df.tail(10)[["show_id", "title"]])
# Out:
#      show_id                                        title
# 8737   s8836                             Avengers Endgame
# 8738   s8837                      Guardians of the Galaxy
# 8739   s8838                Guardians of the Galaxy Vol 2
# 8740   s8839                               Doctor Strange
# 8741   s8840  Doctor Strange in the Multiverse of Madness
# 8742   s8841                                Black Panther
# 8743   s8842                Black Panther Wakanda Forever
# 8744   s8843                        Spider-Man Homecoming
# 8745   s8844                     Spider-Man Far From Home
# 8746   s8845                       Spider-Man No Way Home

# %%
df[df['title'].str.contains('Iron', case=False, na=False)][['show_id','title']]
# Out:
#      show_id                                              title
# 3194   s3195                       Iron Fists and Kung-Fu Kicks
# 3259   s3260                          Iron Sky: The Coming Race
# 3341   s3342           Mobile Suit Gundam: Iron-Blooded Orphans
# 3519   s3520  Kabaneri of the Iron Fortress: The Battle of U...
# 3912   s3913                                  Generation Iron 3
# 4118   s4119                                        Iron Ladies
# 4655   s4656                                 Marvel's Iron Fist
# 5240   s5241                                  Generation Iron 2
# 7054   s7097             Iron Cowboy: The Story of the 50.50.50
# 7055   s7098          Iron Man & Captain America: Heroes United
# 7056   s7099                       Iron Man: Armored Adventures
# 7362   s7416            Marvel's Iron Man & Hulk: Heroes United
# 8283   s8370                                      The Iron Lady
# 8724   s8823                                           Iron Man
# 8725   s8824                                         Iron Man 2
# 8726   s8825                                         Iron Man 3
